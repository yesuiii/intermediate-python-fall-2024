# %% [markdown]
# # Object Oriented Programming Exercises
#
# Complete these exercises to test your skills!

# %% [markdown]
# ## Exercise #1
#
# Create a class named "Dog" that has two properties, breed and age.

# %%
# Your code here
# write your code here
class Dog():
    def __init__(self, breed, age):
        self.breed = breed
        self.age = age

# %% [markdown]
# ## Exercise #2
#
# Create a child class "Puppies" that inherits all the properties of the "Dog" class.

# %%
# Your code here
class Puppies(Dog):
    def __init__(self, breed, age):
        super().__init__(breed, age)

# %%
Puppies("Jaki", 12)

# %% [markdown]
# ## Exercise #3
#
# Create a custom Exception class called AgeError. You should then copy your Dog class from above and modify it to give the AgeError if a negative age is entered.

# %%
# Your code here
class AgeError(Exception):
    pass

# %%
class Dog():
    def __init__(self, breed, age):
        if age < 1:
            raise AgeError("That is impossible. Dog's can't have that age!")
            
        self.breed = breed
        self.age = age

# %%
Dog("Jaki", -1)
# Out:
# ---------------------------------------------------------------------------
# AgeError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Dog("Jaki", -1)
#
# Cell In[9], line 4, in Dog.__init__(self, breed, age)
#       2 def __init__(self, breed, age):
#       3     if age < 1:
# ----> 4         raise AgeError("That is impossible. Dog's can't have that age!")
#       6     self.breed = breed
#       7     self.age = age
#
# AgeError: That is impossible. Dog's can't have that age!
