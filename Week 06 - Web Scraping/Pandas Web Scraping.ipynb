# %% [markdown]
# # Pandas Web Scraping

# %%
import pandas as pd

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2022')

# %%
df = dfs[0]

# %%
df.columns = ['entry_date', 'single', 'artist',
              'peak','peak_date','weeks_top_top',
              'ref']

# %%
df.head()
# Out:
#           entry_date                          single  \
# 0          October 2  "Thats What I Want"[E][G][H] ↑
# 1         October 23               "Shivers"[B] (#5)
# 2        November 13       "Heat Waves"[B][I] † (#1)
# 3  Singles from 2022               Singles from 2022
# 4         January 15     "We Don't Talk About Bruno"
#
#                                               artist               peak  \
# 0                                          Lil Nas X                  8
# 1                                         Ed Sheeran                  4
# 2                                      Glass Animals                  1
# 3                                  Singles from 2022  Singles from 2022
# 4  Carolina Gaitán, Mauro Castillo, Adassa, Rhenz...                  1
#
#            peak_date      weeks_top_top                ref
# 0            April 2                  9             [2][3]
# 1         January 15                 19             [4][5]
# 2           March 12                 37             [6][7]
# 3  Singles from 2022  Singles from 2022  Singles from 2022
# 4         February 5                 13             [5][8]

# %% [markdown]
# ## Doing the same thing with BeautifulSoup4

# %%
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_Billboard_Hot_100_top-ten_singles_in_2022')

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content)

# %%
pd.read_html(str(soup.find('table')))[0]
# Out:
#    Top ten entry date                             Single  \
#     Singles from 2021                  Singles from 2021
# 0           October 2     "Thats What I Want"[E][G][H] ↑
# 1          October 23                  "Shivers"[B] (#5)
# 2         November 13          "Heat Waves"[B][I] † (#1)
# 3   Singles from 2022                  Singles from 2022
# 4          January 15        "We Don't Talk About Bruno"
# ..                ...                                ...
# 71        November 19             "Privileged Rappers" ↑
# 72        November 19                     "Circo Loco" ↑
# 73        November 19                "BackOutsideBoyz" ↑
# 74        December 17  "Superhero (Heroes & Villains)" ↑
# 75        December 24                 "Nobody Gets Me" ↑
#
#                                             Artist(s)               Peak  \
#                                     Singles from 2021  Singles from 2021
# 0                                           Lil Nas X                  8
# 1                                          Ed Sheeran                  4
# 2                                       Glass Animals                  1
# 3                                   Singles from 2022  Singles from 2022
# 4   Carolina Gaitán, Mauro Castillo, Adassa, Rhenz...                  1
# ..                                                ...                ...
# 71                                Drake and 21 Savage                  7
# 72                                Drake and 21 Savage                  8
# 73                                              Drake                  9
# 74               Metro Boomin, Future and Chris Brown                  8
# 75                                                SZA                 10
#
#             Peak date   Weeks in top ten               Ref.
#     Singles from 2021  Singles from 2021  Singles from 2021
# 0             April 2                  9             [2][3]
# 1          January 15                 19             [4][5]
# 2            March 12                 37             [6][7]
# 3   Singles from 2022  Singles from 2022  Singles from 2022
# 4          February 5                 13             [5][8]
# ..                ...                ...                ...
# 71        November 19                  1               [44]
# 72        November 19                  1               [44]
# 73        November 19                  1               [44]
# 74        December 17                  1               [45]
# 75        December 24                  1               [46]
#
# [76 rows x 7 columns]
